# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Toggle input cells."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Toggle input cells."></form>

# %%
from IPython import display
from IPython.display import Image

# %% [markdown]
# ## Plots of H2 Adiabat at various T$_{g}$ and p$_{s}$:

# %%
Image(filename='H2_Adiabats.png')

# %% [markdown]
# ## Graph (a) comparing OLR spectra at 10 bar with blackbody radiation from surface
# Does this confirm what you think about the greenhouse effect? The larger absorption feature doesn't really overlap with the surface BB, and the smaller feature overlaps less with the peak as Tg increases.

# %%
Image(filename='spectral_OLR.png')
