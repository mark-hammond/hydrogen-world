# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Toggle input cells."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Toggle input cells."></form>

# %%
from IPython import display
from IPython.display import Image

# %% [markdown]
# ## Plots of H2 Adiabat at various T$_{g}$ and p$_{s}$:

# %%
Image(filename='H2_Adiabats.png')

# %% [markdown]
# ## Graph (a) comparing OLR spectra at 10 bar with blackbody radiation from surface
# The smaller absorption feature is significant at these temperatures, although it becomes less significant as T increases. As you can see, the larger feature isn't really involved.
#
# It's not really very transparent at these wavelengths, but maybe the greenhouse effect is tempered by the absorption decreasing at T goes over 3000K?
#
# I've got an equivalent graph varying p$_{s}$ at 2800K which I can show you -  it's pretty much the same thing but with varying absorption.

# %%
Image(filename='spectral_OLR.png')

# %% [markdown]
# ## Graphs (b) and (c) showing brightness T and radiating level for 3 bar, 2800K
# I used 3 bar here to get a radiating level that varies through the atmosphere, rather than the more binary level at 10 bar
#
# Do these tell us any more than the graphs above? I guess they're relevant to the observed T in the Demory paper

# %%
Image(filename='rad_level.png')
